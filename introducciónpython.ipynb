# %% [markdown]
# <img src="img/itq.png" width="600">
#
# # Introducción a Python
#
# <img src="img/python.jpg" width="300">
#
# **Nombre:** *Maiccol Zurita*
# **Fecha:** *07/01/2026*

# %%
#Comentario de python
print("Esto es python")
# Out:
# Esto es python
